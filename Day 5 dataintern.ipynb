# %%
#Programmer name:Pratik Joshi
#College: Keystone School Of Engineering
#Class: TE (B)
#Roll No: 58

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('student3.csv')

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df['age'].mean()
# Out:
# 20.785714285714285

# %%
df['marks '].mean()
# Out:
# 66.96714285714286

# %%
df.columns = df.columns.str.strip()

# %%
df['marks'].mean()
# Out:
# 66.96714285714286

# %%
# Find total number of students present in respective classes.

# %%
df = pd.DataFrame(df)
df.dropna(subset=['class'],inplace=True)
class_counts=df['class'].value_counts()
print(class_counts)
# Out:
# class
# TE    9
# BE    4
# be    2
# Name: count, dtype: int64

# %%
df['class']=df['class'].str.upper()

# %%
df.dropna(subset=['class'],inplace=True)
class_c=df['class'].value_counts()
print(class_c)
# Out:
# class
# TE    9
# BE    6
# Name: count, dtype: int64

# %%
df.name
# Out:
# 0        anil
# 1        amit
# 2      aniket
# 3     ajinkya
# 4        asha
# 5      ayesha
# 6        amar
# 7       Amita
# 8        amol
# 9        amol
# 10      anmol
# 11     surbhi
# 12      Sujay
# 13    subhash
# 15    shalini
# Name: name, dtype: object

# %%
df.name=df.name.str.title()

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 15    False
# dtype: bool

# %%
df.isnull()
# Out:
#      roll   name  class  marks    age
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False   True
# 5   False  False  False   True  False
# 6   False  False  False  False  False
# 7   False  False  False  False  False
# 8   False  False  False  False  False
# 9   False  False  False  False  False
# 10  False  False  False  False   True
# 11  False  False  False   True  False
# 12  False  False  False  False  False
# 13  False  False  False  False  False
# 15  False  False  False  False  False

# %%
False + False
# Out:
# 0

# %%
df.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     1
# 6     0
# 7     0
# 8     0
# 9     0
# 10    1
# 11    1
# 12    0
# 13    0
# 15    0
# dtype: int64

# %%
df.dropna(subset=['class'],inplace=True)

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.dropna(subset=['marks'],inplace=True)

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df1 = pd.read_csv('student3.csv')

# %%
df1
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df1.columns = df.columns.str.strip()

# %%
mean_marks = df1['marks'].mean()
df1['marks'] = df1['marks'].fillna(mean_marks)

print(df1)
# Out:
#     roll     name class      marks   age
# 0      1     anil    TE  56.770000  22.0
# 1      2     amit    TE  59.770000  21.0
# 2      3   aniket    BE  76.880000  19.0
# 3      4  ajinkya    TE  69.660000  20.0
# 4      5     asha    TE  63.280000   NaN
# 5      6   ayesha    BE  66.967143  20.0
# 6      7     amar    BE  65.340000  19.0
# 7      8    Amita    be  68.330000  23.0
# 8      9     amol    TE  56.750000  20.0
# 9      9     amol    TE  56.750000  20.0
# 10    10    anmol    BE  78.660000   NaN
# 11    11   surbhi    TE  66.967143  23.0
# 12    12    Sujay    TE  74.120000  22.0
# 13    13  subhash    be  88.450000  21.0
# 14    14   sachin   NaN  59.330000  21.0
# 15    15  shalini    TE  63.450000  20.0

# %%
df1
# Out:
#     roll     name class      marks   age
# 0      1     anil    TE  56.770000  22.0
# 1      2     amit    TE  59.770000  21.0
# 2      3   aniket    BE  76.880000  19.0
# 3      4  ajinkya    TE  69.660000  20.0
# 4      5     asha    TE  63.280000   NaN
# 5      6   ayesha    BE  66.967143  20.0
# 6      7     amar    BE  65.340000  19.0
# 7      8    Amita    be  68.330000  23.0
# 8      9     amol    TE  56.750000  20.0
# 9      9     amol    TE  56.750000  20.0
# 10    10    anmol    BE  78.660000   NaN
# 11    11   surbhi    TE  66.967143  23.0
# 12    12    Sujay    TE  74.120000  22.0
# 13    13  subhash    be  88.450000  21.0
# 14    14   sachin   NaN  59.330000  21.0
# 15    15  shalini    TE  63.450000  20.0

# %%
df2 = pd.read_csv('student3.csv')

# %%
df2
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df2.columns = df.columns.str.strip()

# %%
df2
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28   NaN
# 5      6   ayesha    BE    NaN  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66   NaN
# 11    11   surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    be  88.45  21.0
# 14    14   sachin   NaN  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df2.dropna()
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    be  88.45  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df2.ffill()
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28  20.0
# 5      6   ayesha    BE  63.28  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66  20.0
# 11    11   surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    be  88.45  21.0
# 14    14   sachin    be  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df2.bfill()
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28  20.0
# 5      6   ayesha    BE  65.34  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66  23.0
# 11    11   surbhi    TE  74.12  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    be  88.45  21.0
# 14    14   sachin    TE  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %% [raw]
# Outliers Detection

# %%
import numpy as np

# %%
np.random.randint(1,100)
# Out:
# 19

# %%
sal = []
for i in range(100):
    num = np.random.randint(20000,35000)
    sal.append(num)

# %%
sal
# Out:
# [26551,
#  24023,
#  20714,
#  22785,
#  28063,
#  23635,
#  20448,
#  31326,
#  24963,
#  27479,
#  31455,
#  21424,
#  24735,
#  29769,
#  21378,
#  32213,
#  32837,
#  29390,
#  28897,
#  27651,
#  22421,
#  21138,
#  34455,
#  24674,
#  32051,
#  28650,
#  21313,
#  33033,
#  28536,
#  34250,
#  25891,
#  33380,
#  34183,
#  26208,
#  25138,
#  34336,
#  22023,
#  26120,
#  22370,
#  29915,
#  25069,
#  32662,
#  26334,
#  33570,
#  22012,
#  30174,
#  25501,
#  24926,
#  22084,
#  31733,
#  20294,
#  22268,
#  25310,
#  20021,
#  20191,
#  30162,
#  21848,
#  22269,
#  23531,
#  24696,
#  34604,
#  24451,
#  32089,
#  28096,
#  31221,
#  25355,
#  25957,
#  32309,
#  29197,
#  23209,
#  21438,
#  33891,
#  26022,
#  27573,
#  24274,
#  28395,
#  23459,
#  24379,
#  26494,
#  31768,
#  20059,
#  21690,
#  29624,
#  30365,
#  20688,
#  24642,
#  26537,
#  25293,
#  29070,
#  26439,
#  23451,
#  32866,
#  29791,
#  26042,
#  31976,
#  20750,
#  28488,
#  28653,
#  20678,
#  21846]

# %%
df4 = pd.DataFrame({'salary': sal})

# %%
df4
# Out:
#     salary
# 0    26551
# 1    24023
# 2    20714
# 3    22785
# 4    28063
# ..     ...
# 95   20750
# 96   28488
# 97   28653
# 98   20678
# 99   21846
#
# [100 rows x 1 columns]

# %%
df4.iloc[23,:] = 44000

# %%
df4.iloc[81:] = 47800

# %%
df4.drop(columns=['sal'], inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df4);

# %%
df4.plot.box()
# Out:
# <Axes: >

# %%
newdf = df4[df4['salary']< 40000]

# %%
newdf.shape
# Out:
# (80, 1)

# %%
df4.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df4.shape
# Out:
# (100, 1)

# %%
df4.describe()
# Out:
#              salary
# count    100.000000
# mean   30962.420000
# std     9249.100603
# min    20021.000000
# 25%    24211.250000
# 50%    28245.500000
# 75%    33964.000000
# max    47800.000000

# %%
Q1 = np.percentile(df4['salary'],25)
Q3 = np.percentile(df4['salary'],75)

# %%
Q1,Q3
# Out:
# (24211.25, 33964.0)

# %%
IQR = Q3 - Q1

# %%
IQR
# Out:
# 9752.75

# %%
Upper_fence = Q3 + IQR *1.5
lower_fence = Q1 - IQR * 1.5

# %%
Upper_fence,lower_fence
# Out:
# (48593.125, 9582.125)

# %%
outliers = (df4['salary']> Upper_fence) | (df4['salary'] < lower_fence)

# %%
outliers.shape
# Out:
# (100,)
